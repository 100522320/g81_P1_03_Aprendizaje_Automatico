# %% [markdown]
# # Práctica 1 - Predicción de Subscripción a un Producto Bancario
# **Miembros del grupo:**
#
# Christian Cano -> 100522320
#
# Adrián Curell -> 100522128
#
# [Repositorio de github](https://github.com/100522320/g81_P1_03_Aprendizaje_Automatico.git)
